# %%
# !pip install latex
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting latex
#   Downloading latex-0.7.0.tar.gz (6.5 kB)
# Collecting tempdir
#   Downloading tempdir-0.7.1.tar.gz (5.9 kB)
# Collecting data
#   Downloading data-0.4.tar.gz (7.0 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from latex) (0.16.0)
# Collecting shutilwhich
#   Downloading shutilwhich-1.1.0.tar.gz (2.3 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from data->latex) (1.15.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from data->latex) (4.4.2)
# Collecting funcsigs
#   Downloading funcsigs-1.0.2-py2.py3-none-any.whl (17 kB)
# Building wheels for collected packages: latex, data, shutilwhich, tempdir
#   Building wheel for latex (setup.py) ... done
#   Created wheel for latex: filename=latex-0.7.0-py3-none-any.whl size=7604 sha256=0bdf7d308ce1c71e4c73c822eb1823011948b2dba93aaaf13a531d8f7a851a14
#   Stored in directory: /root/.cache/pip/wheels/57/d6/11/5d5718227890d9e479b6137cb406410c37a0b84b2ab35b872b
#   Building wheel for data (setup.py) ... done
#   Created wheel for data: filename=data-0.4-py3-none-any.whl size=7247 sha256=beb93c221917fab216943df58624ad33139739bc90d7b831449de18d59e418eb
#   Stored in directory: /root/.cache/pip/wheels/28/76/4b/7db27e02c1de4d2181559d108fcdfed1680ff7d3534553d460
#   Building wheel for shutilwhich (setup.py) ... done
#   Created wheel for shutilwhich: filename=shutilwhich-1.1.0-py3-none-any.whl size=2781 sha256=70593a92fe0ed4bbee55b209a3ccd144fa2101b28983c72c2cddcb578f39ba57
#   Stored in directory: /root/.cache/pip/wheels/4c/c0/ce/5a47f35186acbe73e38811df30daaf798c81a7599bb2d5995a
#   Building wheel for tempdir (setup.py) ... done
#   Created wheel for tempdir: filename=tempdir-0.7.1-py3-none-any.whl size=2214 sha256=ab4021058fba017fd5f9747438e6f786ebdba9daec6f14dcc96beff19c42a93c
#   Stored in directory: /root/.cache/pip/wheels/7a/f1/d7/124b54c21a9ba4973bc60fcda6cdc264271f3c4d607be0486d
# Successfully built latex data shutilwhich tempdir
# Installing collected packages: funcsigs, tempdir, shutilwhich, data, latex
# Successfully installed data-0.4 funcsigs-1.0.2 latex-0.7.0 shutilwhich-1.1.0 tempdir-0.7.1

# %% [markdown]
# \begin{align}
#         P(A | B) = \frac{P(B | A) P(A)}{P(B)}.
#     \end{align}

# %%
import pandas as pd

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00373/drug_consumption.data"
dataset = pd.read_csv(url)

# %%
dataset.head()
# Out:
#    1  0.49788  0.48246  -0.05921  0.96082  0.12600  0.31287  -0.57545  \
# 0  2 -0.07854 -0.48246   1.98437  0.96082 -0.31685 -0.67825   1.93886
# 1  3  0.49788 -0.48246  -0.05921  0.96082 -0.31685 -0.46725   0.80523
# 2  4 -0.95197  0.48246   1.16365  0.96082 -0.31685 -0.14882  -0.80615
# 3  5  0.49788  0.48246   1.98437  0.96082 -0.31685  0.73545  -1.63340
# 4  6  2.59171  0.48246  -1.22751  0.24923 -0.31685 -0.67825  -0.30033
#
#    -0.58331  -0.91699  ...  CL0.4  CL0.5  CL0.6 CL0.7 CL0.8 CL0.9 CL0.10  \
# 0   1.43533   0.76096  ...    CL4    CL0    CL2   CL0   CL2   CL3    CL0
# 1  -0.84732  -1.62090  ...    CL0    CL0    CL0   CL0   CL0   CL0    CL1
# 2  -0.01928   0.59042  ...    CL0    CL0    CL2   CL0   CL0   CL0    CL0
# 3  -0.45174  -0.30172  ...    CL1    CL0    CL0   CL1   CL0   CL0    CL2
# 4  -1.55521   2.03972  ...    CL0    CL0    CL0   CL0   CL0   CL0    CL0
#
#   CL2.2 CL0.11 CL0.12
# 0   CL4    CL0    CL0
# 1   CL0    CL0    CL0
# 2   CL2    CL0    CL0
# 3   CL2    CL0    CL0
# 4   CL6    CL0    CL0
#
# [5 rows x 32 columns]
