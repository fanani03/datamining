# %% [markdown]
# # Tugas 9 - Regresi Linier

# %% [markdown]
# Membuat linier regresi dengan 1 fitur

# %%
from sklearn.datasets import make_regression
from matplotlib import pyplot
import numpy as np

# %%
# Membuat data dengan 1 fitur

X_test, y_test = make_regression(n_samples=150, n_features=1, noise=10)
pyplot.scatter(X_test, y_test)
pyplot.show()

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_test, y_test)

# %%
reg.coef_
# Out:
# array([65.41945749])

# %%
reg.intercept_
# Out:
# 0.31751899925645566

# %%
reg.score(X_test, y_test)
# Out:
# 0.9753580702623541

# %%
pyplot.scatter(X_test, y_test)
y_plot = reg.coef_*X_test+reg.intercept_

pyplot.plot(X_test, y_plot, color ='r')
pyplot.show()

# %%
reg.predict([[-3]])
# Out:
# array([-195.94085346])
